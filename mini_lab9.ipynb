# %% [markdown]
# ![9.png](attachment:193f6576-b76f-4979-8772-1637f800c3b1.png)

# %%
file = open('text_file_t.txt')
m = [int(i) for i in file]
print('Изначальный массив:',m)
mx = -10**8
for i in range(len(m)):
    mx = max(mx,m[i])
for i in range(len(m)-1):
    if m[i] == mx:
        m[i+1] = m[i+1]*2
print('Измененный массив: ',m)
# Out:
# Изначальный массив: [6, 7, 8, 9, 6, 7, 8, 9, 40, 5, 6, 6, 7, 8]
# Измененный массив:  [6, 7, 8, 9, 6, 7, 8, 9, 40, 10, 6, 6, 7, 8]
